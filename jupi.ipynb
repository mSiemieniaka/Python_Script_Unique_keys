# %%
import pandas as pd
import os 

current_directory = os.getcwd()
input_file_path = os.path.join(current_directory, "data.csv")
df = pd.read_csv(input_file_path)
df
# Out:
#                          Column1     Column2  \
# 0                       timeUnix  logMessage
# 1    Mar 25, 2024 @ 14:48:10.785    Response
# 2    Mar 25, 2024 @ 14:47:59.625    Response
# 3    Mar 25, 2024 @ 14:47:48.665    Response
# 4    Mar 25, 2024 @ 14:47:37.644    Response
# ..                           ...         ...
# 153  Mar 25, 2024 @ 13:58:59.672    Response
# 154  Mar 25, 2024 @ 13:51:45.215    Response
# 155  Mar 25, 2024 @ 13:49:17.013    Response
# 156  Mar 25, 2024 @ 13:49:15.680    Response
# 157  Mar 25, 2024 @ 13:49:15.016    Response
#
#                                                Column3  \
# 0                                        data.str.body
# 1    {"exceptionID":0,"message":"An unexpected erro...
# 2    {"exceptionID":0,"message":"An unexpected erro...
# 3    {"exceptionID":0,"message":"An unexpected erro...
# 4    {"exceptionID":0,"message":"An unexpected erro...
# ..                                                 ...
# 153  {"exceptionID":0,"message":"An unexpected erro...
# 154  {"exceptionID":0,"message":"An unexpected erro...
# 155  {"exceptionID":259901,"message":"You cannot cr...
# 156  {"exceptionID":259901,"message":"You cannot cr...
# 157  {"exceptionID":259901,"message":"You cannot cr...
#
#                                                Column4
# 0                                    data.str.restPath
# 1    POST http://perseus/service-ng/api/vehicle/v1/...
# 2    POST http://perseus/service-ng/api/vehicle/v1/...
# 3    POST http://perseus/service-ng/api/vehicle/v1/...
# 4    POST http://perseus/service-ng/api/vehicle/v1/...
# ..                                                 ...
# 153  PUT http://perseus/service-ng/api/offboard/v1/...
# 154  PUT http://perseus/service-ng/api/offboard/v1/...
# 155  POST http://perseus/service-ng/api/offboard/v1...
# 156  POST http://perseus/service-ng/api/offboard/v1...
# 157  POST http://perseus/service-ng/api/offboard/v1...
#
# [158 rows x 4 columns]
